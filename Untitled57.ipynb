# %%
import random
def Enviorment(RandomEnviorment):
    RandomEnviorment.update({'L':random.randint(0, 1),'R':random.randint(0, 1)})
    print(RandomEnviorment)
def DetectAndClean(RandomEnviorment):
    VacuumLocation = random.choice(['L', 'R'])
    print(VacuumLocation)
    if(VacuumLocation=='L'):
        if(RandomEnviorment['L']==1 and RandomEnviorment['R']==1):
            print("1")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    ....   ||    ....   |")
            print("  |    ....   ||    ....   |")
            print("  |___________||___________|")

            print("Vacuum Is On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||    ....   |")
            print("  |   /____\  ||    ....   |")
            print("  |___________||___________|")

            
            print("Location L Is Dirty ... ")
            print("Location L Is Cleaned... ")
            RandomEnviorment['L']=0
            print("Vacuum Moved On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Dirty ... ")
            print("Location R Is Cleaned... ")
            
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 
            RandomEnviorment['R']=0
            return
    if(VacuumLocation=='R'):
        if(RandomEnviorment['L']==1 and RandomEnviorment['R']==1):
            print("2")
            
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    ....   ||    ....   |")
            print("  |    ....   ||    ....   |")
            print("  |___________||___________|")
            print("Vacuum Is On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    ....   ||    _/\_   |")
            print("  |    ....   ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Dirty ... ")
            print("Location R Is Cleaned... ")
           
            RandomEnviorment['R']=0
            print("Vacuum Moved On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||           |")
            print("  |   /____\  ||           |")
            print("  |___________||___________|")
            print("Location L Is Dirty ... ")
            print("Location L Is Cleaned... ")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            RandomEnviorment['L']=0  
            return
    if(VacuumLocation=='L'):
        if(RandomEnviorment['L']==0 and RandomEnviorment['R']==1):
            print("3")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    ....   |")
            print("  |           ||    ....   |")
            print("  |___________||___________|")
            print("Vacuum Is On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||    ....   |")
            print("  |   /____\  ||    ....   |")
            print("  |___________||___________|")
            print("Location L Is Cleaned... ")
            print("Vacuum Moved On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Dirty ... ")
            print("Location R Is Cleaned... ")
            RandomEnviorment['R']=0
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            return
    if(VacuumLocation=='R'):
        if(RandomEnviorment['L']==0 and RandomEnviorment['R']==1):
            print("4")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    ....   |")
            print("  |           ||    ....   |")
            print("  |___________||___________|")

            print("Vacuum Is On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Dirty ... ")
            print("Location R Is Cleaned... ")
            print("Vacuum Moved On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||           |")
            print("  |   /____\  ||           |")
            print("  |___________||___________|")
            print("Location L Is Cleaned... ")
            RandomEnviorment['R']=0
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            return
    if(VacuumLocation=='R'):
        
        if(RandomEnviorment['L']==1 and RandomEnviorment['R']==0):
            print("5")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    ....   ||           |")
            print("  |    ....   ||           |")
            print("  |___________||___________|")
            print("Vacuum Is On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            
            print("Location R Is Cleaned... ")
            print("Vacuum Moved On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||           |")
            print("  |   /____\  ||           |")
            print("  |___________||___________|")
            print("Location L Is Dirty ... ")
            print("Location L Is Cleaned... ")
            
            RandomEnviorment['L']=0
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            return
    if(VacuumLocation=='L'):
        if(RandomEnviorment['L']==1 and RandomEnviorment['R']==0):
            print("6")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    ....   ||           |")
            print("  |    ....   ||           |")
            print("  |___________||___________|")
            print("Vacuum Is On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||           |")
            print("  |   /____\  ||           |")
            print("  |___________||___________|")
            print("Location L Is Dirty ... ")
            print("Location L Is Cleaned... ")
            print("Vacuum Moved On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Cleaned... ")
            RandomEnviorment['L']=0
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            return
    if(VacuumLocation=='L'):
        if(RandomEnviorment['L']==0 and RandomEnviorment['R']==0):
            print("7")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            print("Vacuum Is On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||           |")
            print("  |   /____\  ||           |")
            print("  |___________||___________|")
            print("Location L Is Cleaned... ")
            print("Vacuum Moved On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Cleaned... ")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            return
    if(VacuumLocation=='R'):
        if(RandomEnviorment['L']==0 and RandomEnviorment['R']==0):
            print("8")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            print("Vacuum Is On Location 'R'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||    _/\_   |")
            print("  |           ||   /____\  |")
            print("  |___________||___________|")
            print("Location R Is Cleaned... ")
            print("Vacuum Moved On Location 'L'....")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |    _/\_   ||           |")
            print("  |   /____\  ||           |")
            print("  |___________||___________|")
            print("Location L Is Cleaned... ")
            print("     LEFT(L)    RIGHT(R)")
            print("   ___________  ___________")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |           ||           |")
            print("  |___________||___________|") 

            return
RandomEnviorment={}
Enviorment(RandomEnviorment)
DetectAndClean(RandomEnviorment)
print(RandomEnviorment)
# Out:
# {'L': 0, 'R': 0}
# R
# 8
#      LEFT(L)    RIGHT(R)
#    ___________  ___________
#   |           ||           |
#   |           ||           |
#   |           ||           |
#   |___________||___________|
# Vacuum Is On Location 'R'....
#      LEFT(L)    RIGHT(R)
#    ___________  ___________
#   |           ||           |
#   |           ||    _/\_   |
#   |           ||   /____\  |
#   |___________||___________|
# Location R Is Cleaned...
# Vacuum Moved On Location 'L'....
#      LEFT(L)    RIGHT(R)
#    ___________  ___________
#   |           ||           |
#   |    _/\_   ||           |
#   |   /____\  ||           |
#   |___________||___________|
# Location L Is Cleaned...
#      LEFT(L)    RIGHT(R)
#    ___________  ___________
#   |           ||           |
#   |           ||           |
#   |           ||           |
#   |___________||___________|
# {'L': 0, 'R': 0}
